# %% [markdown]
# # 02. 검사환경 변수를 생성 파라미터로 정의하기
#
# 실제 설비에서 흔들리는 변수를 synthetic generator가 조절할 수 있는 parameter로 분해합니다.

# %%
from pathlib import Path
import sys

NOTEBOOK_DIR = Path.cwd()
if not (NOTEBOOK_DIR / "synthetic_metal_utils.py").exists():
    search_roots = [Path.cwd(), *Path.cwd().parents]
    search_patterns = ["synthetic_metal_utils.py", "*/synthetic_metal_utils.py", "*/*/synthetic_metal_utils.py"]
    for root in search_roots:
        for pattern in search_patterns:
            matches = list(root.glob(pattern))
            if matches:
                NOTEBOOK_DIR = matches[0].parent
                break
        if (NOTEBOOK_DIR / "synthetic_metal_utils.py").exists():
            break

sys.path.append(str(NOTEBOOK_DIR))
DATA_ROOT = NOTEBOOK_DIR / "data" / "synthetic_metal_seg"

from synthetic_metal_utils import *
set_korean_font()
set_seed(7)

print("NOTEBOOK_DIR:", NOTEBOOK_DIR)
print("DATA_ROOT:", DATA_ROOT)

# %% [markdown]
# ## 기본 domain spec 확인
#
# DomainSpec은 split, 조명, 각도, 재질, glare 확률을 한 묶음으로 정의합니다.

# %%
domains = default_generation_config()["domains"]
[(d["domain_id"], d["split"], d["light_rgb"], d["camera_angle"], d["material"]) for d in domains]

# %% [markdown]
# ## samples.csv column
#
# 모든 sample은 이후 분석을 위해 동일한 metadata column을 가져야 합니다.

# %%
SAMPLES_COLUMNS

# %% [markdown]
# ## domain별 의도
#
# train에서 본 조건과 일부러 보지 않은 조건을 분리합니다.

# %%
for spec in DEFAULT_DOMAIN_SPECS:
    print(f'{spec.split:20s} {spec.domain_id:28s} light={spec.light_rgb} angle={spec.camera_angle} material={spec.material}')
