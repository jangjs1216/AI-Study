# %% [markdown]
# # 08. Domain Metadata와 Holdout Split 생성
#
# 공용 SyntheticMetalSeg dataset을 실제 파일 구조로 생성합니다.

# %%
from pathlib import Path
import sys

NOTEBOOK_DIR = Path.cwd()
if not (NOTEBOOK_DIR / "synthetic_metal_utils.py").exists():
    search_roots = [Path.cwd(), *Path.cwd().parents]
    search_patterns = ["synthetic_metal_utils.py", "*/synthetic_metal_utils.py", "*/*/synthetic_metal_utils.py"]
    for root in search_roots:
        for pattern in search_patterns:
            matches = list(root.glob(pattern))
            if matches:
                NOTEBOOK_DIR = matches[0].parent
                break
        if (NOTEBOOK_DIR / "synthetic_metal_utils.py").exists():
            break

sys.path.append(str(NOTEBOOK_DIR))
DATA_ROOT = NOTEBOOK_DIR / "data" / "synthetic_metal_seg"

from synthetic_metal_utils import *
set_korean_font()
set_seed(7)

print("NOTEBOOK_DIR:", NOTEBOOK_DIR)
print("DATA_ROOT:", DATA_ROOT)

# %% [markdown]
# ## 데이터셋 생성
#
# 기본 설정은 빠른 실험용 크기입니다. 필요하면 n_train과 n_eval_per_split을 늘리면 됩니다.

# %%
dataset_root = create_synthetic_metal_dataset(
    DATA_ROOT,
    image_size=128,
    n_train=360,
    n_eval_per_split=72,
    seed=7,
    overwrite=True,
)
print(dataset_root)

# %% [markdown]
# ## split과 domain 확인
#
# split_config, domains, samples.csv가 이후 장의 공용 계약입니다.

# %%
summary = inspect_dataset(DATA_ROOT)
summary

# %% [markdown]
# ## metadata 파일 확인
#
# samples.csv에는 모든 생성 조건이 저장됩니다.

# %%
rows = read_samples(DATA_ROOT)
len(rows), rows[0]
